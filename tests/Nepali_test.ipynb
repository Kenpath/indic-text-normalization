# %% [markdown]
# # Nepali Text Normalization Test Cases
#
# This notebook tests the Nepali text normalization implementation.
#
# ## Test Categories:
# 1. Cardinal Numbers
# 2. Decimal Numbers
# 3. Fractions
# 4. Dates
# 5. Time
# 6. Money
# 7. Measurements
# 8. Ordinal Numbers
# 9. Telephone Numbers
# 10. Whitelist/Abbreviations
# 11. Mixed Content
# 12. Batch Testing

# %%
import sys
import os

# Add the NeMo-text-processing directory to the path
sys.path.insert(0, os.path.abspath('.'))

from nemo_text_processing.text_normalization.normalize import Normalizer

print("Imports successful!")
# Out:
# Imports successful!

# %%
# Initialize Nepali normalizer
normalizer_ne = Normalizer(
    input_case='cased',
    lang='ne',
    cache_dir=None,  # Set to a directory path if you want to cache .far files
    overwrite_cache=False,
    post_process=True
)

print("Nepali Text Normalizer initialized successfully!")
print(f"Language: {normalizer_ne.lang}")
# Out:
# Nepali Text Normalizer initialized successfully!
# Language: ne

# %% [markdown]
# ## 1. Cardinal Numbers Test

# %%
cardinal_tests = [
    "155=100",
    "१२३४",
    "१२३४५",
    "१२३४५६",
    "१२३४५६७",
    "१२३४५६७८",
    "-१२३",
    "-120",
    "१०००",
    "१०००००",  # 1 lakh
    "१००००००००",
    "456",
    "9943206870",
    "1,234,566"
]

print("=" * 60)
print("CARDINAL NUMBERS TEST")
print("=" * 60)
for test in cardinal_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# CARDINAL NUMBERS TEST
# ============================================================
# Input:  155=100         -> Output: एक सय पचपन्न बराबर एक सय
# Input:  १२३४            -> Output: एक हजार दुई सय चौँतीस
# Input:  १२३४५           -> Output: बाह्र हजार तीन सय पैँतालीस
# Input:  १२३४५६          -> Output: एक लाख तेइस हजार चार सय छपन्न
# Input:  १२३४५६७         -> Output: बाह्र लाख चौँतीस हजार पाँच सय सतसट्ठी
# Input:  १२३४५६७८        -> Output: एक करोड तेइस लाख पैँतालीस हजार छ सय अठहत्तर
# Input:  -१२३            -> Output:  माइनस एक सय तेइस
# Input:  -120            -> Output:  माइनस एक सय बीस
# Input:  १०००            -> Output: एक हजार
# Input:  १०००००          -> Output: एक लाख
# Input:  १००००००००       -> Output: दश करोड
# Input:  456             -> Output: चार सय छपन्न
# Input:  9943206870      -> Output: नौ अर्ब चौरान्नब्बे करोड बत्तीस लाख छ हजार आठ सय सत्तरी
# Input:  1,234,566       -> Output: एक अल्पविराम दुई सय चौँतीस अल्पविराम पाँच सय छैसट्ठी

# %% [markdown]
# ## 1.2. Time Test (English Digits)

# %%
# Test English digits for time - should work now!
time_tests_english = [
    "12:30",
    "1:40",
    "12:00",
    "12:14",
    "12:30:45",
    "9:15",
    "09:15",
    "23:59",
    "12:49",
]

print("=" * 60)
print("TIME TEST (ENGLISH DIGITS)")
print("=" * 60)
for test in time_tests_english:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# TIME TEST (ENGLISH DIGITS)
# ============================================================
# Input:  12:30           -> Output: बाह्र बजकर तीस मिनट
# Input:  1:40            -> Output: एक बजकर चालीस मिनट
# Input:  12:00           -> Output: बाह्र बजे
# Input:  12:14           -> Output: बाह्र बजकर चौध मिनट
# Input:  12:30:45        -> Output: बाह्र बजकर तीस मिनट पैँतालीस सेकंड
# Input:  9:15            -> Output: नौ बजकर पन्ध्र मिनट
# Input:  09:15           -> Output: नौ बजकर पन्ध्र मिनट
# Input:  23:59           -> Output: तेइस बजकर उनन्साठी मिनट
# Input:  12:49           -> Output: बाह्र बजकर उनन्चास मिनट

# %% [markdown]
# ## 1.3. Money Test (English Digits)

# %%
# Test English digits for money - should work now!
money_tests_english = [
    "₹100",
    "₹1234",
    "₹50.50",
    "₹0.50",
    "₹1000000",
    "₹1050000",
    "₹500",
]

print("=" * 60)
print("MONEY TEST (ENGLISH DIGITS)")
print("=" * 60)
for test in money_tests_english:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
#  NeMo-text-processing :: WARNING  :: Failed text: ₹50.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹50.50Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹0.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹0.50Operation failed
# ============================================================
# MONEY TEST (ENGLISH DIGITS)
# ============================================================
# Input:  ₹100            -> Output: एक सय रुपैयाँ
# Input:  ₹1234           -> Output: एक हजार दुई सय चौँतीस रुपैयाँ
# Input:  ₹50.50          -> Output: ₹50.50
# Input:  ₹0.50           -> Output: ₹0.50
# Input:  ₹1000000        -> Output: दश लाख रुपैयाँ
# Input:  ₹1050000        -> Output: दश लाख पचास हजार रुपैयाँ
# Input:  ₹500            -> Output: पाँच सय रुपैयाँ

# %% [markdown]
# ## 2. Decimal Numbers Test

# %%
# Test both Devanagari and English digits for decimals
decimal_tests = [
    "१२.३४",      # Devanagari digits
    "१२३.४५६",    # Devanagari digits
    "०.५",         # Devanagari digits
    "-१२.३४",     # Devanagari digits
    "१२.३४५६",    # Devanagari digits
    "12.34",        # English digits
    "123.456",      # English digits
    "0.5",          # English digits
    "-12.34",       # English digits
    "96.3456",      # English digits
]

print("=" * 60)
print("DECIMAL NUMBERS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in decimal_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# DECIMAL NUMBERS TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  १२.३४           -> Output: बाह्र दशमलव तीन चार
# Input:  १२३.४५६         -> Output: एक सय तेइस दशमलव चार पाँच छ
# Input:  ०.५             -> Output: शून्य दशमलव पाँच
# Input:  -१२.३४          -> Output:  ऋणात्मक बाह्र दशमलव तीन चार
# Input:  १२.३४५६         -> Output: बाह्र दशमलव तीन चार पाँच छ
# Input:  12.34           -> Output: बाह्र दशमलव तीन चार
# Input:  123.456         -> Output: एक सय तेइस दशमलव चार पाँच छ
# Input:  0.5             -> Output: शून्य दशमलव पाँच
# Input:  -12.34          -> Output:  ऋणात्मक बाह्र दशमलव तीन चार
# Input:  96.3456         -> Output: छयान्नब्बे दशमलव तीन चार पाँच छ

# %% [markdown]
# ## 3. Fractions Test

# %%
# Test both Devanagari and English digits for fractions
fraction_tests = [
    "३/४",         # Devanagari digits
    "१/२",         # Devanagari digits
    "१/४",         # Devanagari digits
    "१२३/४",      # Devanagari digits
    "-१/२",        # Devanagari digits
    "3/4",          # English digits
    "1/2",          # English digits
    "1/4",          # English digits
    "23/4",       # English digits
    "-1/2",         # English digits
]

print("=" * 60)
print("FRACTIONS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in fraction_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# FRACTIONS TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  ३/४             -> Output: तीन बटा चार
# Input:  १/२             -> Output: एक बटा दुई
# Input:  १/४             -> Output: एक बटा चार
# Input:  १२३/४           -> Output: एक सय तेइस बटा चार
# Input:  -१/२            -> Output:  ऋणात्मक एक बटा दुई
# Input:  3/4             -> Output: तीन बटा चार
# Input:  1/2             -> Output: एक बटा दुई
# Input:  1/4             -> Output: एक बटा चार
# Input:  23/4            -> Output: तेइस बटा चार
# Input:  -1/2            -> Output:  ऋणात्मक एक बटा दुई

# %% [markdown]
# ## 4. Dates Test

# %%
# Test both Devanagari and English digits for dates
date_tests = [
    "०१-०४-२०२४",      # Devanagari digits
    "१५-०६-२०२४",      # Devanagari digits
    "२०२४-०१-१५",      # Devanagari digits
    "१५/०६/२०२४",      # Devanagari digits
    "०४-०१-२०२४",      # MM-DD format, Devanagari digits
    "01-04-2024",        # English digits
    "15-06-2024",        # English digits
    "2024-01-15",        # English digits
    "15/06/2024",        # English digits
    "04-01-2024",        # MM-DD format, English digits
]

print("=" * 60)
print("DATES TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in date_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# DATES TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  ०१-०४-२०२४      -> Output: एक अप्रिल दुई हजार चौबीस
# Input:  १५-०६-२०२४      -> Output: पन्ध्र जुन दुई हजार चौबीस
# Input:  २०२४-०१-१५      -> Output: दुई हजार चौबीस माइनस शून्य एक माइनस पन्ध्र
# Input:  १५/०६/२०२४      -> Output: पन्ध्र जुन दुई हजार चौबीस
# Input:  ०४-०१-२०२४      -> Output: चार जनवरी दुई हजार चौबीस
# Input:  01-04-2024      -> Output: एक अप्रिल दुई हजार चौबीस
# Input:  15-06-2024      -> Output: पन्ध्र जुन दुई हजार चौबीस
# Input:  2024-01-15      -> Output: दुई हजार चौबीस माइनस शून्य एक माइनस पन्ध्र
# Input:  15/06/2024      -> Output: पन्ध्र जुन दुई हजार चौबीस
# Input:  04-01-2024      -> Output: चार जनवरी दुई हजार चौबीस

# %% [markdown]
# ## 5. Time Test

# %%
# Test both Devanagari and English digits for time
time_tests = [
    "१२:३०",         # Devanagari digits
    "१:४०",          # Devanagari digits
    "१२:००",         # Devanagari digits
    "१२:३०:४५",      # Devanagari digits
    "०९:१५",         # Devanagari digits
    "२३:५९",         # Devanagari digits
    "12:30",          # English digits
    "1:40",           # English digits
    "12:00",          # English digits
    "12:30:45",       # English digits
    "09:15",          # English digits
    "23:59",          # English digits
    "9:15",           # English digits (single digit hour)
]

print("=" * 60)
print("TIME TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in time_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# TIME TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  १२:३०           -> Output: साढ़े बाह्र
# Input:  १:४०            -> Output: एक बजकर चालीस मिनट
# Input:  १२:००           -> Output: बाह्र बजे
# Input:  १२:३०:४५        -> Output: बाह्र बजकर तीस मिनट पैँतालीस सेकंड
# Input:  ०९:१५           -> Output: नौ बजकर पन्ध्र मिनट
# Input:  २३:५९           -> Output: तेइस बजकर उनन्साठी मिनट
# Input:  12:30           -> Output: बाह्र बजकर तीस मिनट
# Input:  1:40            -> Output: एक बजकर चालीस मिनट
# Input:  12:00           -> Output: बाह्र बजे
# Input:  12:30:45        -> Output: बाह्र बजकर तीस मिनट पैँतालीस सेकंड
# Input:  09:15           -> Output: नौ बजकर पन्ध्र मिनट
# Input:  23:59           -> Output: तेइस बजकर उनन्साठी मिनट
# Input:  9:15            -> Output: नौ बजकर पन्ध्र मिनट

# %% [markdown]
# ## 6. Money Test

# %%
# Test both Devanagari and English digits for money
money_tests = [
    "₹१००",         # Devanagari digits
    "₹१२३४",        # Devanagari digits
    "₹५०.५०",       # Devanagari digits
    "₹०.५०",        # Devanagari digits
    "रू १०००",      # Devanagari digits
    "₹100",          # English digits
    "₹1234",         # English digits
    "₹50.50",        # English digits
    "₹0.50",         # English digits
    "₹1000",         # English digits
    "₹500",          # English digits
]

print("=" * 60)
print("MONEY TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in money_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
#  NeMo-text-processing :: WARNING  :: Failed text: ₹५०.५०Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹५०.५०Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹०.५०Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹०.५०Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹50.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹50.50Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹0.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹0.50Operation failed
# ============================================================
# MONEY TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  ₹१००            -> Output: एक सय रुपैयाँ
# Input:  ₹१२३४           -> Output: एक हजार दुई सय चौँतीस रुपैयाँ
# Input:  ₹५०.५०          -> Output: ₹५०.५०
# Input:  ₹०.५०           -> Output: ₹०.५०
# Input:  रू १०००         -> Output: रू एक हजार
# Input:  ₹100            -> Output: एक सय रुपैयाँ
# Input:  ₹1234           -> Output: एक हजार दुई सय चौँतीस रुपैयाँ
# Input:  ₹50.50          -> Output: ₹50.50
# Input:  ₹0.50           -> Output: ₹0.50
# Input:  ₹1000           -> Output: एक हजार रुपैयाँ
# Input:  ₹500            -> Output: पाँच सय रुपैयाँ

# %% [markdown]
# ## 7. Measurements Test

# %%
# Test both Devanagari and English digits for measurements
measure_tests = [
    "१२ kg",         # Devanagari digits
    "१२५ kg",        # Devanagari digits
    "१०० m",         # Devanagari digits
    "५ km",          # Devanagari digits
    "१२.३४ cm",      # Devanagari digits
    "12 kg",          # English digits
    "125 kg",         # English digits
    "100 m",          # English digits
    "5 km",           # English digits
    "12.34 cm",       # English digits
]

print("=" * 60)
print("MEASUREMENTS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in measure_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# MEASUREMENTS TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  १२ kg           -> Output: बाह्र किलोग्राम
# Input:  १२५ kg          -> Output: एक सय पच्चीस किलोग्राम
# Input:  १०० m           -> Output: एक सय मिटर
# Input:  ५ km            -> Output: पाँच किलोमिटर
# Input:  १२.३४ cm        -> Output: बाह्र दशमलव तीन चार सेन्टिमिटर
# Input:  12 kg           -> Output: बाह्र किलोग्राम
# Input:  125 kg          -> Output: एक सय पच्चीस किलोग्राम
# Input:  100 m           -> Output: एक सय मिटर
# Input:  5 km            -> Output: पाँच किलोमिटर
# Input:  12.34 cm        -> Output: बाह्र दशमलव तीन चार सेन्टिमिटर

# %% [markdown]
# ## 8. Ordinal Numbers Test

# %%
# Test both Devanagari and English digits for ordinals
ordinal_tests = [
    "१औं",           # Devanagari digits
    "२औं",           # Devanagari digits
    "१०औं",          # Devanagari digits
    "२१औं",          # Devanagari digits
    "१००औं",         # Devanagari digits
    "1औं",            # English digits with Devanagari suffix
    "2औं",            # English digits with Devanagari suffix
    "10औं",           # English digits with Devanagari suffix
    "21औं",           # English digits with Devanagari suffix
    "100औं",          # English digits with Devanagari suffix
]

print("=" * 60)
print("ORDINAL NUMBERS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in ordinal_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")

# %% [markdown]
# ## 9. Telephone Numbers Test

# %%
telephone_tests = [
    "मेरो मोबाइल नम्बर +९१५७११४००७",
    "+९१ ९२१०५१५६०६",
    "मेरो मोबाइल नम्बर १३७४३०९९८८",
    "9943206292",
    "9943206292",
    "1,234,567"
]

print("=" * 60)
print("TELEPHONE NUMBERS TEST")
print("=" * 60)
for test in telephone_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:20} -> Output: {result}")

# %% [markdown]
# ## 10. Whitelist/Abbreviations Test

# %%
whitelist_tests = [
    "डा.",
    "प्रो.",
    "श्री",
    "कि.मी.",
    "मी.",
]

print("=" * 60)
print("WHITELIST/ABBREVIATIONS TEST")
print("=" * 60)
for test in whitelist_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")

# %% [markdown]
# ## 11. Mixed Content Test

# %%
mixed_tests = [
    "आज १५-०६-२०२४ मा १२:३० बजे बैठक छ.",
    "₹१००० र ₹५०० जोड्दा ₹१५०० हुन्छ.",
    "१२३ किलोग्राम तौल र ५० किलोमिटर दूरी.",
    "पहिलो स्थान र दोस्रो स्थान.",
    "मेरो मोबाइल नम्बर 9876543210 हो."
]

print("=" * 60)
print("MIXED CONTENT TEST")
print("=" * 60)
for test in mixed_tests:
    result = normalizer_ne.normalize(test)
    print(f"Input:  {test}")
    print(f"Output: {result}")
    print("-" * 60)

# %% [markdown]
# ## 12. Batch Testing

# %%
# Test multiple inputs at once
batch_tests = [
    "123",
    "१२.३४",
    "१२:३०",
    "₹१००",
    "१५-०६-२०२४",
]

print("=" * 60)
print("BATCH TESTING")
print("=" * 60)
results = normalizer_ne.normalize_list(batch_tests)
for input_text, output_text in zip(batch_tests, results):
    print(f"Input:  {input_text:15} -> Output: {output_text}")

# %% [markdown]
# ## Summary
#
# All test cases have been executed. Check the outputs above to verify that Nepali text normalization is working correctly for all categories.
#
# ### Usage Tips:
# - Run each cell sequentially (Shift+Enter)
# - Modify test cases in any cell to test your own inputs
# - Use `verbose=True` in normalize() to see detailed processing information
# - Set `cache_dir` to a directory path to speed up subsequent runs
