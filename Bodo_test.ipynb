# %% [markdown]
# # Bodo Text Normalization Test Cases
#
# This notebook tests the Bodo text normalization implementation.
#
# ## Test Categories:
# 1. Cardinal Numbers
# 2. Decimal Numbers
# 3. Fractions
# 4. Dates
# 5. Time
# 6. Money
# 7. Measurements
# 8. Ordinal Numbers
# 9. Telephone Numbers
# 10. Whitelist/Abbreviations
# 11. Mixed Content
# 12. Batch Testing

# %%
import sys
import os

# Add the NeMo-text-processing directory to the path
sys.path.insert(0, os.path.abspath('.'))

from nemo_text_processing.text_normalization.normalize import Normalizer

print("Imports successful!")
# Out:
# Imports successful!

# %%
# Initialize Bodo normalizer
normalizer_bo = Normalizer(
    input_case='cased',
    lang='bo',
    cache_dir=None,  # Set to a directory path if you want to cache .far files
    overwrite_cache=False,
    post_process=True
)

print("Bodo Text Normalizer initialized successfully!")
print(f"Language: {normalizer_bo.lang}")
# Out:
# Bodo Text Normalizer initialized successfully!
# Language: bo

# %% [markdown]
# ## 1. Cardinal Numbers Test

# %%
cardinal_tests = [
    "155=100",
    "१२३४",
    "१२३४५",
    "१२३४५६",
    "१२३४५६७",
    "१२३४५६७८",
    "-१२३",
    "-120",
    "१०००",
    "१०००००",  # 1 lakh
    "१००००००००",
    "456",
    "9943206870",
    "1,234,566"
]

print("=" * 60)
print("CARDINAL NUMBERS TEST")
print("=" * 60)
for test in cardinal_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# CARDINAL NUMBERS TEST
# ============================================================
# Input:  155=100         -> Output: से सौ बास्सेबा बराबर से सौ
# Input:  १२३४            -> Output: से हज़ार नै सौ थामस्सेब्रै
# Input:  १२३४५           -> Output: स्सेनै हज़ार थाम सौ ब्रैस्सेबा
# Input:  १२३४५६          -> Output: से लाख नैस्सेथाम हज़ार ब्रै सौ बास्सेरो
# Input:  १२३४५६७         -> Output: स्सेनै लाख थामस्सेब्रै हज़ार बा सौ रोस्सेसनि
# Input:  १२३४५६७८        -> Output: से करोड़ नैस्सेथाम लाख ब्रैस्सेबा हज़ार रो सौ सनिस्सेदाम
# Input:  -१२३            -> Output:  माइनस से सौ नैस्सेथाम
# Input:  -120            -> Output:  माइनस से सौ नैस्से
# Input:  १०००            -> Output: से हज़ार
# Input:  १०००००          -> Output: से लाख
# Input:  १००००००००       -> Output: स्से करोड़
# Input:  456             -> Output: ब्रै सौ बास्सेरो
# Input:  9943206870      -> Output: स्को अरब स्कोस्सेब्रै करोड़ थामस्सेनै लाख रो हज़ार दाम सौ सनिस्से
# Input:  1,234,566       -> Output: से कमा नै सौ थामस्सेब्रै कमा बा सौ रोस्सेरो

# %% [markdown]
# ## 1.2. Time Test (English Digits)

# %%
# Test English digits for time - should work now!
time_tests_english = [
    "12:30",
    "1:40",
    "12:00",
    "12:14",
    "12:30:45",
    "9:15",
    "09:15",
    "23:59",
    "12:49",
]

print("=" * 60)
print("TIME TEST (ENGLISH DIGITS)")
print("=" * 60)
for test in time_tests_english:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# TIME TEST (ENGLISH DIGITS)
# ============================================================
# Input:  12:30           -> Output: स्सेनै बजकर थामस्से मिनट
# Input:  1:40            -> Output: से बजकर ब्रैस्से मिनट
# Input:  12:00           -> Output: स्सेनै बजे
# Input:  12:14           -> Output: स्सेनै बजकर स्सेब्रै मिनट
# Input:  12:30:45        -> Output: स्सेनै बजकर थामस्से मिनट ब्रैस्सेबा सेकंड
# Input:  9:15            -> Output: स्को बजकर स्सेबा मिनट
# Input:  09:15           -> Output: स्को बजकर स्सेबा मिनट
# Input:  23:59           -> Output: नैस्सेथाम बजकर बास्सेस्को मिनट
# Input:  12:49           -> Output: स्सेनै बजकर ब्रैस्सेस्को मिनट

# %% [markdown]
# ## 1.3. Money Test (English Digits)

# %%
# Test English digits for money - should work now!
money_tests_english = [
    "₹100",
    "₹1234",
    "₹50.50",
    "₹0.50",
    "₹1000000",
    "₹1050000",
    "₹500",
]

print("=" * 60)
print("MONEY TEST (ENGLISH DIGITS)")
print("=" * 60)
for test in money_tests_english:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
#  NeMo-text-processing :: WARNING  :: Failed text: ₹50.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹50.50Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹0.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹0.50Operation failed
# ============================================================
# MONEY TEST (ENGLISH DIGITS)
# ============================================================
# Input:  ₹100            -> Output: से सौ रुपै
# Input:  ₹1234           -> Output: से हज़ार नै सौ थामस्सेब्रै रुपै
# Input:  ₹50.50          -> Output: ₹50.50
# Input:  ₹0.50           -> Output: ₹0.50
# Input:  ₹1000000        -> Output: स्से लाख रुपै
# Input:  ₹1050000        -> Output: स्से लाख बास्से हज़ार रुपै
# Input:  ₹500            -> Output: बा सौ रुपै

# %% [markdown]
# ## 2. Decimal Numbers Test

# %%
# Test both Devanagari and English digits for decimals
decimal_tests = [
    "१२.३४",      # Devanagari digits
    "१२३.४५६",    # Devanagari digits
    "०.५",         # Devanagari digits
    "-१२.३४",     # Devanagari digits
    "१२.३४५६",    # Devanagari digits
    "12.34",        # English digits
    "123.456",      # English digits
    "0.5",          # English digits
    "-12.34",       # English digits
    "96.3456",      # English digits
]

print("=" * 60)
print("DECIMAL NUMBERS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in decimal_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# DECIMAL NUMBERS TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  १२.३४           -> Output: स्सेनै दशमलव थाम ब्रै
# Input:  १२३.४५६         -> Output: से सौ नैस्सेथाम दशमलव ब्रै बा रो
# Input:  ०.५             -> Output: लाबा दशमलव बा
# Input:  -१२.३४          -> Output:  ऋणात्मक स्सेनै दशमलव थाम ब्रै
# Input:  १२.३४५६         -> Output: स्सेनै दशमलव थाम ब्रै बा रो
# Input:  12.34           -> Output: स्सेनै दशमलव थाम ब्रै
# Input:  123.456         -> Output: से सौ नैस्सेथाम दशमलव ब्रै बा रो
# Input:  0.5             -> Output: लाबा दशमलव बा
# Input:  -12.34          -> Output:  ऋणात्मक स्सेनै दशमलव थाम ब्रै
# Input:  96.3456         -> Output: स्कोस्सेरो दशमलव थाम ब्रै बा रो

# %% [markdown]
# ## 3. Fractions Test

# %%
# Test both Devanagari and English digits for fractions
fraction_tests = [
    "३/४",         # Devanagari digits
    "१/२",         # Devanagari digits
    "१/४",         # Devanagari digits
    "१२३/४",      # Devanagari digits
    "-१/२",        # Devanagari digits
    "3/4",          # English digits
    "1/2",          # English digits
    "1/4",          # English digits
    "23/4",       # English digits
    "-1/2",         # English digits
]

print("=" * 60)
print("FRACTIONS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in fraction_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# FRACTIONS TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  ३/४             -> Output: थाम बटा ब्रै
# Input:  १/२             -> Output: से बटा नै
# Input:  १/४             -> Output: से बटा ब्रै
# Input:  १२३/४           -> Output: से सौ नैस्सेथाम बटा ब्रै
# Input:  -१/२            -> Output:  ऋणात्मक से बटा नै
# Input:  3/4             -> Output: थाम बटा ब्रै
# Input:  1/2             -> Output: से बटा नै
# Input:  1/4             -> Output: से बटा ब्रै
# Input:  23/4            -> Output: नैस्सेथाम बटा ब्रै
# Input:  -1/2            -> Output:  ऋणात्मक से बटा नै

# %% [markdown]
# ## 4. Dates Test

# %%
# Test both Devanagari and English digits for dates
date_tests = [
    "०१-०४-२०२४",      # Devanagari digits
    "१५-०६-२०२४",      # Devanagari digits
    "२०२४-०१-१५",      # Devanagari digits
    "१५/०६/२०२४",      # Devanagari digits
    "०४-०१-२०२४",      # MM-DD format, Devanagari digits
    "01-04-2024",        # English digits
    "15-06-2024",        # English digits
    "2024-01-15",        # English digits
    "15/06/2024",        # English digits
    "04-01-2024",        # MM-DD format, English digits
]

print("=" * 60)
print("DATES TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in date_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# DATES TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  ०१-०४-२०२४      -> Output: से एप्रिल नै हज़ार नैस्सेब्रै
# Input:  १५-०६-२०२४      -> Output: स्सेबा जुन नै हज़ार नैस्सेब्रै
# Input:  २०२४-०१-१५      -> Output: नै हज़ार नैस्सेब्रै माइनस लाबा से माइनस स्सेबा
# Input:  १५/०६/२०२४      -> Output: स्सेबा जुन नै हज़ार नैस्सेब्रै
# Input:  ०४-०१-२०२४      -> Output: ब्रै जानुवारी नै हज़ार नैस्सेब्रै
# Input:  01-04-2024      -> Output: से एप्रिल नै हज़ार नैस्सेब्रै
# Input:  15-06-2024      -> Output: स्सेबा जुन नै हज़ार नैस्सेब्रै
# Input:  2024-01-15      -> Output: नै हज़ार नैस्सेब्रै माइनस लाबा से माइनस स्सेबा
# Input:  15/06/2024      -> Output: स्सेबा जुन नै हज़ार नैस्सेब्रै
# Input:  04-01-2024      -> Output: ब्रै जानुवारी नै हज़ार नैस्सेब्रै

# %% [markdown]
# ## 5. Time Test

# %%
# Test both Devanagari and English digits for time
time_tests = [
    "१२:३०",         # Devanagari digits
    "१:४०",          # Devanagari digits
    "१२:००",         # Devanagari digits
    "१२:३०:४५",      # Devanagari digits
    "०९:१५",         # Devanagari digits
    "२३:५९",         # Devanagari digits
    "12:30",          # English digits
    "1:40",           # English digits
    "12:00",          # English digits
    "12:30:45",       # English digits
    "09:15",          # English digits
    "23:59",          # English digits
    "9:15",           # English digits (single digit hour)
]

print("=" * 60)
print("TIME TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in time_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# TIME TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  १२:३०           -> Output: साढ़े स्सेनै
# Input:  १:४०            -> Output: से बजकर ब्रैस्से मिनट
# Input:  १२:००           -> Output: स्सेनै बजे
# Input:  १२:३०:४५        -> Output: स्सेनै बजकर थामस्से मिनट ब्रैस्सेबा सेकंड
# Input:  ०९:१५           -> Output: स्को बजकर स्सेबा मिनट
# Input:  २३:५९           -> Output: नैस्सेथाम बजकर बास्सेस्को मिनट
# Input:  12:30           -> Output: स्सेनै बजकर थामस्से मिनट
# Input:  1:40            -> Output: से बजकर ब्रैस्से मिनट
# Input:  12:00           -> Output: स्सेनै बजे
# Input:  12:30:45        -> Output: स्सेनै बजकर थामस्से मिनट ब्रैस्सेबा सेकंड
# Input:  09:15           -> Output: स्को बजकर स्सेबा मिनट
# Input:  23:59           -> Output: नैस्सेथाम बजकर बास्सेस्को मिनट
# Input:  9:15            -> Output: स्को बजकर स्सेबा मिनट

# %% [markdown]
# ## 6. Money Test

# %%
# Test both Devanagari and English digits for money
money_tests = [
    "₹१००",         # Devanagari digits
    "₹१२३४",        # Devanagari digits
    "₹५०.५०",       # Devanagari digits
    "₹०.५०",        # Devanagari digits
    "रू १०००",      # Devanagari digits
    "₹100",          # English digits
    "₹1234",         # English digits
    "₹50.50",        # English digits
    "₹0.50",         # English digits
    "₹1000",         # English digits
    "₹500",          # English digits
]

print("=" * 60)
print("MONEY TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in money_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
#  NeMo-text-processing :: WARNING  :: Failed text: ₹५०.५०Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹५०.५०Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹०.५०Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹०.५०Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹50.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹50.50Operation failed
#  NeMo-text-processing :: WARNING  :: Failed text: ₹0.50Operation failed
# WARNING:NeMo-text-processing:Failed text: ₹0.50Operation failed
# ============================================================
# MONEY TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  ₹१००            -> Output: से सौ रुपै
# Input:  ₹१२३४           -> Output: से हज़ार नै सौ थामस्सेब्रै रुपै
# Input:  ₹५०.५०          -> Output: ₹५०.५०
# Input:  ₹०.५०           -> Output: ₹०.५०
# Input:  रू १०००         -> Output: रू से हज़ार
# Input:  ₹100            -> Output: से सौ रुपै
# Input:  ₹1234           -> Output: से हज़ार नै सौ थामस्सेब्रै रुपै
# Input:  ₹50.50          -> Output: ₹50.50
# Input:  ₹0.50           -> Output: ₹0.50
# Input:  ₹1000           -> Output: से हज़ार रुपै
# Input:  ₹500            -> Output: बा सौ रुपै

# %% [markdown]
# ## 7. Measurements Test

# %%
# Test both Devanagari and English digits for measurements
measure_tests = [
    "१२ kg",         # Devanagari digits
    "१२५ kg",        # Devanagari digits
    "१०० m",         # Devanagari digits
    "५ km",          # Devanagari digits
    "१२.३४ cm",      # Devanagari digits
    "12 kg",          # English digits
    "125 kg",         # English digits
    "100 m",          # English digits
    "5 km",           # English digits
    "12.34 cm",       # English digits
]

print("=" * 60)
print("MEASUREMENTS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in measure_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# MEASUREMENTS TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  १२ kg           -> Output: स्सेनै किलोग्राम
# Input:  १२५ kg          -> Output: से सौ नैस्सेबा किलोग्राम
# Input:  १०० m           -> Output: से सौ मीटर
# Input:  ५ km            -> Output: बा किलोमीटर
# Input:  १२.३४ cm        -> Output: स्सेनै दशमलव थाम ब्रै सेंटीमीटर
# Input:  12 kg           -> Output: स्सेनै किलोग्राम
# Input:  125 kg          -> Output: से सौ नैस्सेबा किलोग्राम
# Input:  100 m           -> Output: से सौ मीटर
# Input:  5 km            -> Output: बा किलोमीटर
# Input:  12.34 cm        -> Output: स्सेनै दशमलव थाम ब्रै सेंटीमीटर

# %% [markdown]
# ## 8. Ordinal Numbers Test

# %%
# Test both Devanagari and English digits for ordinals
ordinal_tests = [
    "१वां",           # Devanagari digits
    "२वां",           # Devanagari digits
    "१०वां",          # Devanagari digits
    "२१वां",          # Devanagari digits
    "१००वां",         # Devanagari digits
    "1वां",            # English digits with Devanagari suffix
    "2वां",            # English digits with Devanagari suffix
    "10वां",           # English digits with Devanagari suffix
    "21वां",           # English digits with Devanagari suffix
    "100वां",          # English digits with Devanagari suffix
]

print("=" * 60)
print("ORDINAL NUMBERS TEST (DEVANAGARI & ENGLISH DIGITS)")
print("=" * 60)
for test in ordinal_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# ORDINAL NUMBERS TEST (DEVANAGARI & ENGLISH DIGITS)
# ============================================================
# Input:  १वां            -> Output: १वां
# Input:  २वां            -> Output: २वां
# Input:  १०वां           -> Output: १०वां
# Input:  २१वां           -> Output: २१वां
# Input:  १००वां          -> Output: १००वां
# Input:  1वां            -> Output: 1वां
# Input:  2वां            -> Output: 2वां
# Input:  10वां           -> Output: 10वां
# Input:  21वां           -> Output: 21वां
# Input:  100वां          -> Output: 100वां

# %% [markdown]
# ## 9. Telephone Numbers Test

# %%
telephone_tests = [
    "आंनि मोबाइल नम्बर +९१५७११४००७",
    "+९१ ९२१०५१५६०६",
    "आंनि मोबाइल नम्बर १३७४३०९९८८",
    "9943206292",
    "9943206292",
    "1,234,567"
]

print("=" * 60)
print("TELEPHONE NUMBERS TEST")
print("=" * 60)
for test in telephone_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:20} -> Output: {result}")
# Out:
# ============================================================
# TELEPHONE NUMBERS TEST
# ============================================================
# Input:  आंनि मोबाइल नम्बर +९१५७११४००७ -> Output: आंनि मोबाइल नम्बर प्लस स्को अरब स्सेबा करोड़ सनिस्सेसे लाख स्सेब्रै हज़ार सनि
# Input:  +९१ ९२१०५१५६०६       -> Output: प्लस स्को से स्को नै से लाबा बा से बा रो लाबा रो
# Input:  आंनि मोबाइल नम्बर १३७४३०९९८८ -> Output: आंनि मोबाइल नम्बर शून्य से थाम सनि ब्रै थाम लाबा स्को स्को दाम दाम
# Input:  9943206292           -> Output: स्को अरब स्कोस्सेब्रै करोड़ थामस्सेनै लाख रो हज़ार नै सौ स्कोस्सेनै
# Input:  9943206292           -> Output: स्को अरब स्कोस्सेब्रै करोड़ थामस्सेनै लाख रो हज़ार नै सौ स्कोस्सेनै
# Input:  1,234,567            -> Output: से कमा नै सौ थामस्सेब्रै कमा बा सौ रोस्सेसनि

# %% [markdown]
# ## 10. Whitelist/Abbreviations Test

# %%
whitelist_tests = [
    "डा.",
    "प्रो.",
    "श्री",
    "कि.मी.",
    "मी.",
]

print("=" * 60)
print("WHITELIST/ABBREVIATIONS TEST")
print("=" * 60)
for test in whitelist_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test:15} -> Output: {result}")
# Out:
# ============================================================
# WHITELIST/ABBREVIATIONS TEST
# ============================================================
# Input:  डा.             -> Output: डा .
# Input:  प्रो.           -> Output: प्रोफेसर
# Input:  श्री            -> Output: श्री
# Input:  कि.मी.          -> Output: किलोमीटर
# Input:  मी.             -> Output: मीटर

# %% [markdown]
# ## 11. Mixed Content Test

# %%
mixed_tests = [
    "दिनै १५-०६-२०२४ आव १२:३० बजे गुबुन दं.",
    "₹१००० आरो ₹५०० जाबोदों ₹१५०० होनो.",
    "१२३ किलोग्राम जोरसिम आरो ५० किलोमीटर गासै.",
    "१वां थाननि आरो २वां थाननि.",
    "आंनि मोबाइल नम्बर 9876543210."
]

print("=" * 60)
print("MIXED CONTENT TEST")
print("=" * 60)
for test in mixed_tests:
    result = normalizer_bo.normalize(test)
    print(f"Input:  {test}")
    print(f"Output: {result}")
    print("-" * 60)

# %% [markdown]
# ## 12. Batch Testing

# %%
# Test multiple inputs at once
batch_tests = [
    "123",
    "१२.३४",
    "१२:३०",
    "₹१००",
    "१५-०६-२०२४",
]

print("=" * 60)
print("BATCH TESTING")
print("=" * 60)
results = normalizer_bo.normalize_list(batch_tests)
for input_text, output_text in zip(batch_tests, results):
    print(f"Input:  {input_text:15} -> Output: {output_text}")

# %% [markdown]
# ## Summary
#
# All test cases have been executed. Check the outputs above to verify that Bodo text normalization is working correctly for all categories.
#
# ### Usage Tips:
# - Run each cell sequentially (Shift+Enter)
# - Modify test cases in any cell to test your own inputs
# - Use `verbose=True` in normalize() to see detailed processing information
# - Set `cache_dir` to a directory path to speed up subsequent runs
